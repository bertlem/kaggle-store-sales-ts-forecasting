# %% [markdown]
# # IMPORTS

# %%
import numpy as np
import pandas as pd

from datetime import datetime, date
from pathlib import Path

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # PLOTTING PARAMETERS

# %%
plt.style.use("bmh")

plt.rc(
    "figure",
    autolayout=True,
    figsize=(11, 4),
    titlesize=18,
    titleweight='bold',
    )

plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
    )

# %% [markdown]
# # PATHS

# %%
path_data = Path('./input')

# %% [markdown]
# #  FUNCTIONS TO BE SET IN MODULE

# %%
def prepare_seasonal_plot(df):
    
    X = df.copy()

    # days within a week
    X["day"] = X.date.dt.dayofweek  # the x-axis (freq)
    X["week"] = X.date.dt.week  # the seasonal period (period)
    X['dayname'] = X.date.dt.day_name()
    
    # days within a year
    X["dayofyear"] = X.date.dt.dayofyear
    X["year"] = X.date.dt.year

    return X

def seasonal_plot(X, y, period, freq, ax=None):
    
    if ax is None:
        _, ax = plt.subplots()
    palette = sns.color_palette("husl", n_colors=X[period].nunique(),)
    ax = sns.lineplot(
        x=freq,
        y=y,
        hue=period,
        data=X,
        ci=False,
        ax=ax,
        palette=palette,
        legend=False,
    )
    ax.set_title(f"Seasonal Plot ({period}/{freq})")
    for line, name in zip(ax.lines, X[period].unique()):
        y_ = line.get_ydata()[-1]
        ax.annotate(
            name,
            xy=(1, y_),
            xytext=(6, 0),
            color=line.get_color(),
            xycoords=ax.get_yaxis_transform(),
            textcoords="offset points",
            size=14,
            va="center",
        )
    return ax

# %% [markdown]
# # DATA

# %% [markdown]
# ## Store_sales

# %%
store_sales = pd.read_csv(
    path_data / 'train.csv',
    usecols=['store_nbr', 'family', 'date', 'sales', 'onpromotion'],
    dtype={'store_nbr': 'category',
           'family': 'category',
           'sales': 'float32',
          },
    parse_dates=['date'],
    infer_datetime_format=True,
    )

pd.to_datetime(store_sales['date'])

store_sales = prepare_seasonal_plot(store_sales)
# Out:
# /tmp/ipykernel_404992/857166004.py:7: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   X["week"] = X.date.dt.week  # the seasonal period (period)

# %% [markdown]
# fig, (ax0, ax1) = plt.subplots(2, 1, figsize=(11, 6))
# seasonal_plot(store_sales.query("family == 'SEAFOOD'"), y="sales", period="week", freq="day", ax=ax0)
# seasonal_plot(store_sales.query("family == 'SEAFOOD'"), y="sales", period="year", freq="dayofyear", ax=ax1);

# %% [markdown]
# ## Stores

# %%
stores = pd.read_csv(
    path_data / 'stores.csv',
    dtype={'store_nbr': 'category',
           'city': 'category',
           'state': 'category',
           'type': 'category',
           'cluster': 'category'
           },
    )
# type already use as column name
stores.rename(columns={'type': 'store_type'}, inplace=True)
stores.head()
# Out:
#   store_nbr           city                           state store_type cluster
# 0         1          Quito                       Pichincha          D      13
# 1         2          Quito                       Pichincha          D      13
# 2         3          Quito                       Pichincha          D       8
# 3         4          Quito                       Pichincha          D       9
# 4         5  Santo Domingo  Santo Domingo de los Tsachilas          D       4

# %% [markdown]
# ## Test data

# %%
df_test = pd.read_csv(
    path_data / 'test.csv',
    dtype={'store_nbr': 'category',
           'family': 'category',
           'onpromotion': 'uint32',
           },
    parse_dates=['date'],
    infer_datetime_format=True,
    )

pd.to_datetime(df_test['date'])
df_test.head()
# Out:
#         id       date store_nbr      family  onpromotion
# 0  3000888 2017-08-16         1  AUTOMOTIVE            0
# 1  3000889 2017-08-16         1   BABY CARE            0
# 2  3000890 2017-08-16         1      BEAUTY            2
# 3  3000891 2017-08-16         1   BEVERAGES           20
# 4  3000892 2017-08-16         1       BOOKS            0

# %% [markdown]
# ## Holidays_events

# %% [markdown]
# #### DATA DESCRIPTION
#
# Holidays and Events, with metadata
#
# NOTE:
#
# Pay special attention to the transferred column. A holiday that is transferred officially falls on that calendar day, but was moved to another date by the government. A transferred day is more like a normal day than a holiday. To find the day that it was actually celebrated, look for the corresponding row where type is Transfer. For example, the holiday Independencia de Guayaquil was transferred from 2012-10-09 to 2012-10-12, which means it was celebrated on 2012-10-12. Days that are type Bridge are extra days that are added to a holiday (e.g., to extend the break across a long weekend). These are frequently made up by the type Work Day which is a day not normally scheduled for work (e.g., Saturday) that is meant to payback the Bridge. Additional holidays are days added a regular calendar holiday, for example, as typically happens around Christmas (making Christmas Eve a holiday).
#
# ADDITIONAL NOTES:
#
# Wages in the public sector are paid every two weeks on the 15 th and on the last day of the month. Supermarket sales could be affected by this.
#
# A magnitude 7.8 earthquake struck Ecuador on April 16, 2016. People rallied in relief efforts donating water and other first need products which greatly affected supermarket sales for several weeks after the earthquake.

# %%
holidays_events = pd.read_csv(
    path_data / "holidays_events.csv",
    dtype={'type': 'category',
          'locale': 'category',
          'locale_name': 'category',
          'description': 'category',
          'transferred': 'bool',#
          },
    parse_dates=['date'],
    infer_datetime_format=True,
    )

pd.to_datetime(holidays_events['date'])
holidays_events.head()
# Out:
#         date     type    locale locale_name                    description  \
# 0 2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1 2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2 2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3 2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4 2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
holidays_events.type.unique()
# Out:
# ['Holiday', 'Transfer', 'Additional', 'Bridge', 'Work Day', 'Event']
# Categories (6, object): ['Additional', 'Bridge', 'Event', 'Holiday', 'Transfer', 'Work Day']

# %% [markdown]
# - 'Holiday'are holiday,
# - 'Work Day' are extra, unusual work days, meant to compensate for Bridge days
#
# We create a 'status' column to specify if the given day is a work day or a holiday

# %%
holidays_events['status'] = np.nan

# %%
holidays_events.loc[holidays_events.type=='Holiday', 'status'] = 'holiday'
holidays_events.loc[holidays_events.type=='Work Day', 'status'] = 'work'

# %% [markdown]
# NOTE: for a few entries (days), two different events occur on the same day
#
# ALSO: same holiday listed twice under 'bridge' and 'additional'
#
# To facilitate the process,
# - we rename some of the events
# - more importantly, we rename 'Bridge' as 'Additional' and remove (3) duplicate entries
#
# DEAL WITH BRIDGE/ADDITIONAL DUPLICATES

# %%
# cosmetic renaming
holidays_events["description"] = holidays_events["description"].str.replace("Puente ", "")
# rename 'Bridge' as 'Additional'
holidays_events.loc[holidays_events.type=='Bridge', 'type'] = 'Additional'
# select 'Additional' rows
additional = holidays_events.loc[holidays_events.type=='Additional']
print(len(additional))
# drop 'Bridge' vs 'Additional' duplicates
new_additional=additional.drop_duplicates(subset=['date', 'locale'], keep='first', \
                                          inplace=False, ignore_index=False)
print(len(new_additional))

print(len(holidays_events))
# remove 'additional' from the original df
holidays_events.drop(holidays_events.loc[holidays_events['type']=='Additional'].index, inplace=True)
# Appends new_additional (that is, with duplicates removed) to the original df
holidays_events = pd.concat([holidays_events, new_additional], axis=0)
print(len(holidays_events))
# Out:
# 56
# 53
# 350
# 347

# %% [markdown]
# - 'Additional' are holidays

# %%
holidays_events.loc[holidays_events.type=='Additional', 'status'] = 'holiday'

# %% [markdown]
# - 'Transfer' are holidays (initially scheduled another day, transferred to a 'Transfer' day)
#
# Since the initial information on the holiday is provided, there is no need to further manipulated the data to keep track of that

# %%
holidays_events.loc[holidays_events.type=='Transfer', 'status'] = 'holiday'

# %% [markdown]
# - 'Transferred' are work days (initially scheduled as holiday, transferred to a 'Transfer' day)

# %%
holidays_events.loc[holidays_events.transferred=='True', 'status'] = 'work'

# %% [markdown]
# - Events are various, but always National

# %%
event_mask = holidays_events.type == 'Event'
event = holidays_events[event_mask]
print(len(event))
event
# Out:
# 56
#           date   type    locale locale_name  \
# 55  2013-05-12  Event  National     Ecuador
# 103 2014-05-11  Event  National     Ecuador
# 106 2014-06-12  Event  National     Ecuador
# 107 2014-06-15  Event  National     Ecuador
# 108 2014-06-20  Event  National     Ecuador
# 113 2014-06-25  Event  National     Ecuador
# 114 2014-06-28  Event  National     Ecuador
# 115 2014-06-29  Event  National     Ecuador
# 116 2014-06-30  Event  National     Ecuador
# 117 2014-07-01  Event  National     Ecuador
# 120 2014-07-04  Event  National     Ecuador
# 121 2014-07-05  Event  National     Ecuador
# 122 2014-07-08  Event  National     Ecuador
# 123 2014-07-09  Event  National     Ecuador
# 124 2014-07-12  Event  National     Ecuador
# 125 2014-07-13  Event  National     Ecuador
# 144 2014-11-28  Event  National     Ecuador
# 145 2014-12-01  Event  National     Ecuador
# 172 2015-05-10  Event  National     Ecuador
# 198 2015-11-27  Event  National     Ecuador
# 199 2015-11-30  Event  National     Ecuador
# 219 2016-04-16  Event  National     Ecuador
# 220 2016-04-17  Event  National     Ecuador
# 221 2016-04-18  Event  National     Ecuador
# 222 2016-04-19  Event  National     Ecuador
# 223 2016-04-20  Event  National     Ecuador
# 225 2016-04-21  Event  National     Ecuador
# 226 2016-04-22  Event  National     Ecuador
# 227 2016-04-23  Event  National     Ecuador
# 228 2016-04-24  Event  National     Ecuador
# 229 2016-04-25  Event  National     Ecuador
# 230 2016-04-26  Event  National     Ecuador
# 231 2016-04-27  Event  National     Ecuador
# 232 2016-04-28  Event  National     Ecuador
# 233 2016-04-29  Event  National     Ecuador
# 234 2016-04-30  Event  National     Ecuador
# 236 2016-05-01  Event  National     Ecuador
# 237 2016-05-02  Event  National     Ecuador
# 238 2016-05-03  Event  National     Ecuador
# 239 2016-05-04  Event  National     Ecuador
# 240 2016-05-05  Event  National     Ecuador
# 241 2016-05-06  Event  National     Ecuador
# 243 2016-05-07  Event  National     Ecuador
# 244 2016-05-08  Event  National     Ecuador
# 245 2016-05-08  Event  National     Ecuador
# 246 2016-05-09  Event  National     Ecuador
# 247 2016-05-10  Event  National     Ecuador
# 248 2016-05-11  Event  National     Ecuador
# 250 2016-05-12  Event  National     Ecuador
# 251 2016-05-13  Event  National     Ecuador
# 252 2016-05-14  Event  National     Ecuador
# 253 2016-05-15  Event  National     Ecuador
# 254 2016-05-16  Event  National     Ecuador
# 284 2016-11-25  Event  National     Ecuador
# 285 2016-11-28  Event  National     Ecuador
# 311 2017-05-14  Event  National     Ecuador
#
#                                          description  transferred status
# 55                                   Dia de la Madre        False    NaN
# 103                                  Dia de la Madre        False    NaN
# 106            Inauguracion Mundial de futbol Brasil        False    NaN
# 107          Mundial de futbol Brasil: Ecuador-Suiza        False    NaN
# 108       Mundial de futbol Brasil: Ecuador-Honduras        False    NaN
# 113        Mundial de futbol Brasil: Ecuador-Francia        False    NaN
# 114       Mundial de futbol Brasil: Octavos de Final        False    NaN
# 115       Mundial de futbol Brasil: Octavos de Final        False    NaN
# 116       Mundial de futbol Brasil: Octavos de Final        False    NaN
# 117       Mundial de futbol Brasil: Octavos de Final        False    NaN
# 120       Mundial de futbol Brasil: Cuartos de Final        False    NaN
# 121       Mundial de futbol Brasil: Cuartos de Final        False    NaN
# 122            Mundial de futbol Brasil: Semifinales        False    NaN
# 123            Mundial de futbol Brasil: Semifinales        False    NaN
# 124  Mundial de futbol Brasil: Tercer y cuarto lugar        False    NaN
# 125                  Mundial de futbol Brasil: Final        False    NaN
# 144                                     Black Friday        False    NaN
# 145                                     Cyber Monday        False    NaN
# 172                                  Dia de la Madre        False    NaN
# 198                                     Black Friday        False    NaN
# 199                                     Cyber Monday        False    NaN
# 219                                 Terremoto Manabi        False    NaN
# 220                               Terremoto Manabi+1        False    NaN
# 221                               Terremoto Manabi+2        False    NaN
# 222                               Terremoto Manabi+3        False    NaN
# 223                               Terremoto Manabi+4        False    NaN
# 225                               Terremoto Manabi+5        False    NaN
# 226                               Terremoto Manabi+6        False    NaN
# 227                               Terremoto Manabi+7        False    NaN
# 228                               Terremoto Manabi+8        False    NaN
# 229                               Terremoto Manabi+9        False    NaN
# 230                              Terremoto Manabi+10        False    NaN
# 231                              Terremoto Manabi+11        False    NaN
# 232                              Terremoto Manabi+12        False    NaN
# 233                              Terremoto Manabi+13        False    NaN
# 234                              Terremoto Manabi+14        False    NaN
# 236                              Terremoto Manabi+15        False    NaN
# 237                              Terremoto Manabi+16        False    NaN
# 238                              Terremoto Manabi+17        False    NaN
# 239                              Terremoto Manabi+18        False    NaN
# 240                              Terremoto Manabi+19        False    NaN
# 241                              Terremoto Manabi+20        False    NaN
# 243                              Terremoto Manabi+21        False    NaN
# 244                              Terremoto Manabi+22        False    NaN
# 245                                  Dia de la Madre        False    NaN
# 246                              Terremoto Manabi+23        False    NaN
# 247                              Terremoto Manabi+24        False    NaN
# 248                              Terremoto Manabi+25        False    NaN
# 250                              Terremoto Manabi+26        False    NaN
# 251                              Terremoto Manabi+27        False    NaN
# 252                              Terremoto Manabi+28        False    NaN
# 253                              Terremoto Manabi+29        False    NaN
# 254                              Terremoto Manabi+30        False    NaN
# 284                                     Black Friday        False    NaN
# 285                                     Cyber Monday        False    NaN
# 311                                  Dia de la Madre        False    NaN

# %% [markdown]
# Event provides additional information
#
# The earthquake and following days are marked as Terremoto Manabi+XX
#
# In a general case, their impact would have to be dealt with, for instance not including them in the training sample
#
# NB: Assessing their impact can only be done by including multiple years in the training sample, which is out of the scope of the kaggle competition since the training range is et from 2017-05-01 to 2017-08-15
#
# Some other days may have direct (Dia de la Madre, black Friday, cyber Monday) or indirect impact (Mundial de futbol Brasil) on (categorical) sales
#
# Events should be considered as work day (unless they are a holiday for some other reason)

# %%
print(len(holidays_events))
# Add boolean column to keep track of event
holidays_events['Terremoto'] = np.where((holidays_events['type']=='Event') & (holidays_events['description'].str.contains('Terremoto')), True, False)
holidays_events['Futbol'] = np.where((holidays_events['type']=='Event') & (holidays_events['description'].str.contains('futbol')), True, False)
holidays_events['CyberMonday'] = np.where((holidays_events['type']=='Event') & (holidays_events['description'].str.contains('Monday')), True, False)
holidays_events['BlackFriday'] = np.where((holidays_events['type']=='Event') & (holidays_events['description'].str.contains('Friday')), True, False)
holidays_events['Madre'] = np.where((holidays_events['type']=='Event') & (holidays_events['description'].str.contains('Madre')), True, False)
# Remove 'Event' events (the info is preserved via the above commands)
holidays_events = holidays_events.loc[holidays_events.type != 'Event']
print(len(holidays_events))
holidays_events
# Out:
# 347
# 291
#           date        type    locale locale_name  \
# 0   2012-03-02     Holiday     Local       Manta
# 1   2012-04-01     Holiday  Regional    Cotopaxi
# 2   2012-04-12     Holiday     Local      Cuenca
# 3   2012-04-14     Holiday     Local    Libertad
# 4   2012-04-21     Holiday     Local    Riobamba
# ..         ...         ...       ...         ...
# 343 2017-12-21  Additional  National     Ecuador
# 345 2017-12-22  Additional  National     Ecuador
# 346 2017-12-23  Additional  National     Ecuador
# 347 2017-12-24  Additional  National     Ecuador
# 349 2017-12-26  Additional  National     Ecuador
#
#                        description  transferred   status  Terremoto  Futbol  \
# 0               Fundacion de Manta        False  holiday      False   False
# 1    Provincializacion de Cotopaxi        False  holiday      False   False
# 2              Fundacion de Cuenca        False  holiday      False   False
# 3        Cantonizacion de Libertad        False  holiday      False   False
# 4        Cantonizacion de Riobamba        False  holiday      False   False
# ..                             ...          ...      ...        ...     ...
# 343                      Navidad-4        False  holiday      False   False
# 345                      Navidad-3        False  holiday      False   False
# 346                      Navidad-2        False  holiday      False   False
# 347                      Navidad-1        False  holiday      False   False
# 349                      Navidad+1        False  holiday      False   False
#
#      CyberMonday  BlackFriday  Madre
# 0          False        False  False
# 1          False        False  False
# 2          False        False  False
# 3          False        False  False
# 4          False        False  False
# ..           ...          ...    ...
# 343        False        False  False
# 345        False        False  False
# 346        False        False  False
# 347        False        False  False
# 349        False        False  False
#
# [291 rows x 12 columns]

# %% [markdown]
# #### Holidays can be national, regional, or local

# %% [markdown]
# - The location of the store has to be taken into account to verify if a given event is indeed a holiday for a given store
# - This leads to complicated issues, in particular because of duplicated dates

# %% [markdown]
# - The way to go is:
# 1) split holidays_events in national/regional/local
# 2) remove national holidays from regional/local holidays (no need to account for them twice)
# NB: some (descriptive) information is lost in this process
# 2) merge them separately with store_sales+stores, taking into account 'date' AND 'city'/'state'

# %% [markdown]
# ##### Merge Store_sales and stores

# %%
print(len(store_sales))
store_sales2 = store_sales.merge(stores, on='store_nbr', how='left')
store_sales2
len(store_sales2)
# Out:
# 3000888
# 3000888

# %%
national = holidays_events.loc[holidays_events.locale == 'National'].copy()
list_national = national['date'].to_list()
# No duplicated dates
# No NaNs in status

# %%
# Merge store_sales2 with national --> full
nat_merged = store_sales2.merge(national, left_on=['date'], right_on=['date'], how='left') 
print(len(nat_merged))
# Out:
# 3000888

# %%
regional = holidays_events.loc[holidays_events.locale == 'Regional'].copy()
regional.head()
# No duplicated dates
# No NaNs in status
# Out:
#          date     type    locale                     locale_name  \
# 1  2012-04-01  Holiday  Regional                        Cotopaxi
# 7  2012-06-25  Holiday  Regional                        Imbabura
# 23 2012-11-06  Holiday  Regional  Santo Domingo de los Tsachilas
# 24 2012-11-07  Holiday  Regional                     Santa Elena
# 47 2013-04-01  Holiday  Regional                        Cotopaxi
#
#                            description  transferred   status  Terremoto  \
# 1        Provincializacion de Cotopaxi        False  holiday      False
# 7        Provincializacion de Imbabura        False  holiday      False
# 23  Provincializacion de Santo Domingo        False  holiday      False
# 24       Provincializacion Santa Elena        False  holiday      False
# 47       Provincializacion de Cotopaxi        False  holiday      False
#
#     Futbol  CyberMonday  BlackFriday  Madre
# 1    False        False        False  False
# 7    False        False        False  False
# 23   False        False        False  False
# 24   False        False        False  False
# 47   False        False        False  False

# %%
# No overlap between national holidays and regional holidays
print(len(regional))
print(len(regional.loc[~regional.date.isin(list_national)]))
list_regional = regional['date'].to_list()
# Out:
# 24
# 24

# %%
# Merge store_sales2 with regional
reg_merged = store_sales2.merge(regional, left_on=['date', 'state'], right_on=['date', 'locale_name'], how='left', suffixes=[None, '_reg']) 
print(len(reg_merged))
# Out:
# 3000888

# %%
# check that event in the given region are indeed holidays
print(reg_merged.loc[reg_merged.locale_name.isin(reg_merged.state)]['status'].unique())
# check that non-matching region/state are not holidays (NaNs will be filled in later)
print(reg_merged.loc[~reg_merged.locale_name.isin(reg_merged.state)]['status'].unique())
# Out:
# ['holiday']
# [nan]

# %%
local = holidays_events.loc[holidays_events.locale == 'Local'].copy()
local.loc[local.duplicated(subset=['date','locale_name'], keep=False)]
# There are duplicated dates, but they correspond to different cities, except for 2016-07-24 (fundacion de Guayaquil), 
# which is duplicated for the same city
# No NaNs in status
# Out:
#           date        type locale locale_name  \
# 265 2016-07-24    Transfer  Local   Guayaquil
# 264 2016-07-24  Additional  Local   Guayaquil
#
#                          description  transferred   status  Terremoto  Futbol  \
# 265  Traslado Fundacion de Guayaquil        False  holiday      False   False
# 264         Fundacion de Guayaquil-1        False  holiday      False   False
#
#      CyberMonday  BlackFriday  Madre
# 265        False        False  False
# 264        False        False  False

# %%
# remove this duplicated date
print(len(local))
local.drop_duplicates(subset=['date', 'locale_name'], keep='first', inplace=True, ignore_index=False)
print(len(local))
# Out:
# 152
# 151

# %%
# Remove national+regional holidays that were already accounted for from local 
list_natreg = list_national + list_regional
print(len(local))
local_small = local.loc[~local.date.isin(list_natreg)]
print(len(local_small))
local_small
# Out:
# 151
# 131
#           date        type locale locale_name                description  \
# 0   2012-03-02     Holiday  Local       Manta         Fundacion de Manta
# 2   2012-04-12     Holiday  Local      Cuenca        Fundacion de Cuenca
# 3   2012-04-14     Holiday  Local    Libertad  Cantonizacion de Libertad
# 4   2012-04-21     Holiday  Local    Riobamba  Cantonizacion de Riobamba
# 5   2012-05-12     Holiday  Local        Puyo     Cantonizacion del Puyo
# ..         ...         ...    ...         ...                        ...
# 200 2015-12-05  Additional  Local       Quito       Fundacion de Quito-1
# 286 2016-12-05  Additional  Local       Quito       Fundacion de Quito-1
# 321 2017-07-24  Additional  Local   Guayaquil   Fundacion de Guayaquil-1
# 322 2017-07-25  Additional  Local   Guayaquil     Fundacion de Guayaquil
# 339 2017-12-05  Additional  Local       Quito       Fundacion de Quito-1
#
#      transferred   status  Terremoto  Futbol  CyberMonday  BlackFriday  Madre
# 0          False  holiday      False   False        False        False  False
# 2          False  holiday      False   False        False        False  False
# 3          False  holiday      False   False        False        False  False
# 4          False  holiday      False   False        False        False  False
# 5          False  holiday      False   False        False        False  False
# ..           ...      ...        ...     ...          ...          ...    ...
# 200        False  holiday      False   False        False        False  False
# 286        False  holiday      False   False        False        False  False
# 321        False  holiday      False   False        False        False  False
# 322        False  holiday      False   False        False        False  False
# 339        False  holiday      False   False        False        False  False
#
# [131 rows x 12 columns]

# %%
# Merge store_sales2 with local_small
loc_merged = store_sales2.merge(local_small, left_on=['date', 'city'], right_on=['date', 'locale_name'], how='left', suffixes =[None, '_loc']) 
print(len(loc_merged))
# Out:
# 3000888

# %%
# check that event in the given region are indeed holidays
print(loc_merged.loc[loc_merged.locale_name.isin(loc_merged.city)]['status'].unique())
# Out:
# ['holiday']

# %%
# check that non-matching region/city are not holidays (NaNs will be filled in later)
print(loc_merged.loc[~loc_merged.locale_name.isin(loc_merged.city)]['status'].unique())
# Out:
# [nan]

# %%
# concatenate the 3 big dfs (nat_merged, reg_merged, loc_merged)
full=pd.concat([nat_merged, reg_merged, loc_merged], axis=0)

# %%
full=pd.concat([nat_merged, reg_merged, loc_merged], axis=0).sort_values(by='status').drop_duplicates(subset=['date', 'store_nbr', 'family'], keep='first', \
                                                                             inplace=False, ignore_index=False)

# %%
len(full)
# Out:
# 3000888

# %% [raw]
# full.drop_duplicates(subset=['date', 'store_nbr', 'family', 'locale_name'], \
#                      keep='first', inplace=True, ignore_index=True)

# %%
len(full.loc[~full.status.isna()])
# Out:
# 172755

# %%
len(full.loc[~full.locale.isna()])
# Out:
# 172755

# %%
full.loc[full.duplicated(subset=['date', 'store_nbr', 'family'])==True]
# Out:
# Empty DataFrame
# Columns: [date, store_nbr, family, sales, onpromotion, day, week, dayname, dayofyear, year, city, state, store_type, cluster, type, locale, locale_name, description, transferred, status, Terremoto, Futbol, CyberMonday, BlackFriday, Madre]
# Index: []
#
# [0 rows x 25 columns]

# %%
full.locale.unique()
# Out:
# ['National', 'Local', 'Regional', NaN]
# Categories (3, object): ['Local', 'National', 'Regional']

# %%
# fill NaNs in status with workday 
full.loc[full.status.isna(), 'status'] = 'work'
# fill NaNs in various events with False 
full.loc[full.Terremoto.isna(), 'Terremoto'] = False
full.loc[full.Futbol.isna(), 'Futbol'] = False
full.loc[full.CyberMonday.isna(), 'CyberMonday'] = False
full.loc[full.BlackFriday.isna(), 'BlackFriday'] = False
full.loc[full.Madre.isna(), 'Madre'] = False

# %%
# Select relevant columns only
# Basically we get rid of 'type' and 'description'
clean = full[['date', 'store_nbr', 'family', 'sales', 'onpromotion', \
      'city', 'state', 'store_type', 'cluster', 'locale', 'locale_name', \
      'status', 'day', 'dayname', 'dayofyear', 'week', 'year', \
      'Terremoto', 'Futbol', 'CyberMonday', 'BlackFriday', 'Madre']].reset_index(drop=True)
clean.index.name='index'
clean
# Out:
#               date store_nbr                      family        sales  \
# index
# 0       2013-01-01         1                  AUTOMOTIVE     0.000000
# 1       2016-05-07         7                     POULTRY   737.388977
# 2       2016-05-07         7              PREPARED FOODS   225.252991
# 3       2016-05-07         7                     PRODUCE  5946.388184
# 4       2016-05-07         7  SCHOOL AND OFFICE SUPPLIES     0.000000
# ...            ...       ...                         ...          ...
# 3000883 2017-08-15         9                     POULTRY   438.132996
# 3000884 2017-08-15         9              PREPARED FOODS   154.552994
# 3000885 2017-08-15         9                     PRODUCE  2419.729004
# 3000886 2017-08-15         9  SCHOOL AND OFFICE SUPPLIES   121.000000
# 3000887 2017-08-15         9                     SEAFOOD    16.000000
#
#          onpromotion   city      state store_type cluster    locale  ... day  \
# index                                                                ...
# 0                  0  Quito  Pichincha          D      13  National  ...   1
# 1                  0  Quito  Pichincha          D       8  National  ...   5
# 2                  0  Quito  Pichincha          D       8  National  ...   5
# 3                  0  Quito  Pichincha          D       8  National  ...   5
# 4                  0  Quito  Pichincha          D       8  National  ...   5
# ...              ...    ...        ...        ...     ...       ...  ...  ..
# 3000883            0  Quito  Pichincha          B       6       NaN  ...   1
# 3000884            1  Quito  Pichincha          B       6       NaN  ...   1
# 3000885          148  Quito  Pichincha          B       6       NaN  ...   1
# 3000886            8  Quito  Pichincha          B       6       NaN  ...   1
# 3000887            0  Quito  Pichincha          B       6       NaN  ...   1
#
#           dayname  dayofyear week  year  Terremoto  Futbol CyberMonday  \
# index
# 0         Tuesday          1    1  2013      False   False       False
# 1        Saturday        128   18  2016      False   False       False
# 2        Saturday        128   18  2016      False   False       False
# 3        Saturday        128   18  2016      False   False       False
# 4        Saturday        128   18  2016      False   False       False
# ...           ...        ...  ...   ...        ...     ...         ...
# 3000883   Tuesday        227   33  2017      False   False       False
# 3000884   Tuesday        227   33  2017      False   False       False
# 3000885   Tuesday        227   33  2017      False   False       False
# 3000886   Tuesday        227   33  2017      False   False       False
# 3000887   Tuesday        227   33  2017      False   False       False
#
#         BlackFriday  Madre
# index
# 0             False  False
# 1             False  False
# 2             False  False
# 3             False  False
# 4             False  False
# ...             ...    ...
# 3000883       False  False
# 3000884       False  False
# 3000885       False  False
# 3000886       False  False
# 3000887       False  False
#
# [3000888 rows x 22 columns]

# %%
# save clean data as gzipped csv file
filename = path_data / 'clean_data.gz'
print(filename)
clean.to_csv(filename, compression=dict(method='gzip'))
# Out:
# input/clean_data.gz

# %% [raw]
# # create new columns
# holidays_events.loc[holidays_events.description.str.contains("Fundacion"), 'desc2'] = 'fundacion'
# holidays_events.loc[holidays_events.description.str.contains("Provincializacion"), 'desc2'] = 'provincializacion'
# holidays_events.loc[holidays_events.description.str.contains("Cantonizacion"), 'desc2'] = 'cantonizacion'
# holidays_events.loc[holidays_events.description.str.contains("Independencia"), 'desc2'] = 'independencia'

# %% [raw]
# # DatetimeIndex to PeriodIndex
# holidays_events = holidays_events.set_index('date').to_period('D')
# holidays_events.head()
